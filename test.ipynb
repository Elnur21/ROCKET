# %%
from utils.helper import *
from utils.constants import *
from model.ROCKET import ROCKET


df = read_dataset("ArrowHead")

model=ROCKET()

model.compile("ArrowHead",df)
results=[]

for dataset_name in UNIVARIATE_DATASET_NAMES_2018:

    print(f"{dataset_name}".center(80, "-"))
    print(f"Loading data".ljust(80 - 5, "."), end = "", flush = True)
    df = read_dataset(dataset_name)
    print("Done.")
    modelResults, timings = model.fit(df)
    results.append({'Dataset': dataset_name, "results": modelResults, "timings": timings})
    timings_mean = timings.mean(1)
    print(f"{dataset_name} TRAINING FINISHED".center(80, "-"))

    


print(f"ALL TRAINING FINISHED".center(80, "="))
# Out:
# -----------------------------------ArrowHead------------------------------------
# Loading data...............................................................Done.
# Compiling ROCKET functions (once only).....................................Done.
# -----------------------------------ArrowHead------------------------------------
# Loading data...............................................................
# Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# --------------------------ArrowHead TRAINING FINISHED---------------------------
# --------------------------------------Wine--------------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# -----------------------------Wine TRAINING FINISHED-----------------------------
# ------------------------------------OliveOil------------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ---------------------------OliveOil TRAINING FINISHED---------------------------
# --------------------------------------Car---------------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# -----------------------------Car TRAINING FINISHED------------------------------
# -----------------------------------BeetleFly------------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# --------------------------BeetleFly TRAINING FINISHED---------------------------
# --------------------------------------Yoga--------------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# -----------------------------Yoga TRAINING FINISHED-----------------------------
# ----------------------------------InlineSkate-----------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# -------------------------InlineSkate TRAINING FINISHED--------------------------
# ------------------------------------FaceAll-------------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ---------------------------FaceAll TRAINING FINISHED----------------------------
# --------------------------------------Ham---------------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# -----------------------------Ham TRAINING FINISHED------------------------------
# -----------------------------------MoteStrain-----------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# --------------------------MoteStrain TRAINING FINISHED--------------------------
# -------------------------------ProximalPhalanxTW--------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ----------------------ProximalPhalanxTW TRAINING FINISHED-----------------------
# ----------------------------------WordSynonyms----------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# -------------------------WordSynonyms TRAINING FINISHED-------------------------
# -----------------------------------Lightning7-----------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# --------------------------Lightning7 TRAINING FINISHED--------------------------
# -----------------------------GunPointOldVersusYoung-----------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# --------------------GunPointOldVersusYoung TRAINING FINISHED--------------------
# ----------------------------------Earthquakes-----------------------------------
# Loading data...............................................................Done.
# ====================================RUNNING=====================================
# Performing runs............................................................
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# ====================================RUNNING=====================================
# -------------------------Earthquakes TRAINING FINISHED--------------------------
# =============================ALL TRAINING FINISHED==============================

# %%
results_accuracies=list(map(lambda x: {"original":x,"accuracy":np.mean(x["results"])*100},results))

# %%
results_accuracies
# Out:
# [{'original': {'Dataset': 'ArrowHead',
#    'results': array([0.76571429, 0.77142857, 0.78285714, 0.76      , 0.77714286,
#           0.76571429, 0.78857143, 0.77714286, 0.81142857, 0.77714286]),
#    'timings': array([[0.29805995, 0.31612656, 0.31280009, 0.31134069, 0.31699417,
#            0.34945026, 0.31727299, 0.31976414, 0.34872709, 0.32141107],
#           [1.27159627, 1.25005719, 1.19952115, 1.20798139, 1.22399708,
#            1.28392805, 1.21878049, 1.22033132, 1.32234027, 1.43185951],
#           [0.02202105, 0.0223791 , 0.03190627, 0.01033844, 0.0183753 ,
#            0.02386008, 0.01543414, 0.00971498, 0.01371917, 0.02808863],
#           [0.00774823, 0.00928643, 0.0098764 , 0.00927722, 0.00622363,
#            0.00946453, 0.00823893, 0.00642058, 0.00809396, 0.00660379]])},
#   'accuracy': 77.77142857142859},
#  {'original': {'Dataset': 'Wine',
#    'results': array([0.7037037 , 0.72222222, 0.7037037 , 0.7037037 , 0.7037037 ,
#           0.66666667, 0.7037037 , 0.72222222, 0.7037037 , 0.72222222]),
#    'timings': array([[0.4412858 , 0.43628834, 0.42204314, 0.43261582, 0.42938693,
#            0.41116214, 0.43663588, 0.45313924, 0.43949053, 0.42822172],
#           [0.35047386, 0.37485745, 0.35204828, 0.35003749, 0.35952287,
#            0.36001647, 0.35081083, 0.3592615 , 0.35579016, 0.36801206],
#           [0.02924307, 0.03465218, 0.02748464, 0.02485755, 0.03584188,
#            0.04103658, 0.01560072, 0.01517845, 0.01520237, 0.03821185],
#           [0.00339539, 0.00367961, 0.00347544, 0.00362666, 0.00614786,
#            0.00614957, 0.00212374, 0.00218615, 0.00229117, 0.00459053]])},
#   'accuracy': 70.55555555555556},
#  {'original': {'Dataset': 'OliveOil',
#    'results': array([0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8]),
#    'timings': array([[0.51705028, 0.56676454, 0.56138133, 0.54531371, 0.55230771,
#            0.56626148, 0.58229754, 0.57909962, 0.59284927, 0.55025247],
#           [0.51257452, 0.49126936, 0.51251369, 0.49135096, 0.48562896,
#            0.5157225 , 0.50420356, 0.49817993, 0.50811561, 0.48228644],
#           [0.00850737, 0.01133529, 0.03382036, 0.01832089, 0.01731596,
#            0.0161339 , 0.05550417, 0.01724102, 0.00945742, 0.01729256],
#           [0.00190207, 0.00222888, 0.00926004, 0.00200292, 0.00223191,
#            0.00187025, 0.00486177, 0.00465771, 0.00172623, 0.00322502]])},
#   'accuracy': 80.0},
#  {'original': {'Dataset': 'Car',
#    'results': array([0.9       , 0.9       , 0.9       , 0.88333333, 0.9       ,
#           0.9       , 0.9       , 0.91666667, 0.9       , 0.88333333]),
#    'timings': array([[1.01619457, 1.06434713, 1.05214217, 1.0752197 , 1.0541316 ,
#            1.06889167, 1.04072689, 1.09240898, 1.04155007, 1.08490449],
#           [1.01375062, 0.97408243, 0.99237253, 1.02822517, 0.98949681,
#            1.00002488, 1.02203018, 1.06512018, 1.00456256, 1.00159578],
#           [0.01736193, 0.02664034, 0.03809633, 0.01752658, 0.02252385,
#            0.02415189, 0.05293701, 0.0233248 , 0.01662226, 0.03079831],
#           [0.0022172 , 0.00485351, 0.00617855, 0.00356316, 0.00455305,
#            0.00432649, 0.00676755, 0.00350465, 0.00282693, 0.00356888]])},
#   'accuracy': 89.83333333333331},
#  {'original': {'Dataset': 'BeetleFly',
#    'results': array([0.9 , 0.85, 0.85, 0.85, 0.85, 0.9 , 0.85, 0.85, 0.85, 0.85]),
#    'timings': array([[0.31965457, 0.375235  , 0.3738998 , 0.38622678, 0.40390573,
#            0.40200621, 0.38981626, 0.34451033, 0.34335048, 0.36731336],
#           [0.31701242, 0.31648852, 0.322561  , 0.32416346, 0.33881772,
#            0.34133487, 0.30090955, 0.29964978, 0.30225171, 0.29703331],
#           [0.01758681, 0.02792086, 0.01265191, 0.01356635, 0.01544079,
#            0.01331068, 0.03422423, 0.02080816, 0.02237194, 0.02101471],
#           [0.00207016, 0.00254784, 0.00434026, 0.0014266 , 0.00183126,
#            0.00159378, 0.00233367, 0.00150956, 0.00367235, 0.00170567]])},
#   'accuracy': 86.0},
#  {'original': {'Dataset': 'Yoga',
#    'results': array([0.90733333, 0.90466667, 0.89766667, 0.89833333, 0.903     ,
#           0.90266667, 0.91066667, 0.903     , 0.90333333, 0.91266667]),
#    'timings': array([[ 3.51064956,  3.6286485 ,  3.68232162,  3.74008936,  3.81147079,
#             3.60367023,  3.70302344,  3.67688686,  3.65770813,  3.64317239],
#           [34.62831048, 34.75811898, 35.17335581, 34.98208268, 35.08143926,
#            34.98881383, 34.82244148, 34.60396132, 34.30138872, 35.03501836],
#           [ 0.1375041 ,  0.10446664,  0.16417409,  0.11057233,  0.12086835,
#             0.10614066,  0.15491893,  0.14385548,  0.12203217,  0.18251612],
#           [ 0.06939019,  0.06803874,  0.06983468,  0.06871278,  0.08432554,
#             0.07824381,  0.09011432,  0.0953582 ,  0.09327587,  0.11059108]])},
#   'accuracy': 90.43333333333334},
#  {'original': {'Dataset': 'InlineSkate',
#    'results': array([0.40545455, 0.39090909, 0.39636364, 0.38727273, 0.39090909,
#           0.39818182, 0.38363636, 0.38909091, 0.39454545, 0.38545455]),
#    'timings': array([[5.25361013e+00, 5.61214641e+00, 5.50940318e+00, 5.53097364e+00,
#            5.46588576e+00, 5.34642195e+00, 5.42774707e+00, 5.18401784e+00,
#            5.29612360e+00, 5.24649717e+00],
#           [2.84372318e+01, 2.87272440e+01, 2.83805106e+01, 2.89847014e+01,
#            2.87081024e+01, 2.84433697e+01, 2.88155512e+01, 2.87050826e+01,
#            2.91357205e+01, 2.84052042e+01],
#           [5.36555430e-02, 3.32734450e-02, 5.19861030e-02, 3.18791980e-02,
#            4.89475990e-02, 6.42898770e-02, 6.95051880e-02, 7.09478690e-02,
#            5.82085660e-02, 6.96670290e-02],
#           [3.15753700e-02, 1.90439660e-02, 2.25689710e-02, 1.63347380e-02,
#            2.27246380e-02, 3.63491440e-02, 2.43388300e-02, 3.32089140e-02,
#            2.35733030e-02, 2.19021640e-02]])},
#   'accuracy': 39.21818181818181},
#  {'original': {'Dataset': 'FaceAll',
#    'results': array([0.93491124, 0.93313609, 0.93668639, 0.93313609, 0.93136095,
#           0.93372781, 0.93136095, 0.93254438, 0.93609467, 0.93076923]),
#    'timings': array([[2.09454393, 2.0735648 , 2.19177366, 2.09371263, 2.26829142,
#            2.16370696, 2.13552919, 2.14647415, 2.18744799, 2.14922976],
#           [6.30580593, 6.36226025, 6.24303529, 6.11400005, 6.22536876,
#            6.11334056, 6.29366147, 6.38733015, 6.30595782, 6.15794273],
#           [0.29033112, 0.37933813, 0.30410422, 0.31318894, 0.31587547,
#            0.26554983, 0.30873249, 0.31443946, 0.29141733, 0.30007941],
#           [0.06051564, 0.06462369, 0.07236264, 0.05192601, 0.05354923,
#            0.06381157, 0.0530181 , 0.04603628, 0.05933918, 0.06285575]])},
#   'accuracy': 93.33727810650888},
#  {'original': {'Dataset': 'Ham',
#    'results': array([0.68571429, 0.6952381 , 0.7047619 , 0.7047619 , 0.68571429,
#           0.7047619 , 0.6952381 , 0.68571429, 0.7047619 , 0.6952381 ]),
#    'timings': array([[1.37661758, 1.4185662 , 1.41271181, 1.44428357, 1.39601801,
#            1.3912149 , 1.38298755, 1.35565933, 1.41993985, 1.41909241],
#           [1.37330193, 1.31222489, 1.33469154, 1.27245914, 1.32515605,
#            1.30258277, 1.33142386, 1.33758181, 1.31243807, 1.32007951],
#           [0.06835189, 0.06237252, 0.07350761, 0.04907004, 0.03934808,
#            0.05350427, 0.08796016, 0.0462376 , 0.03515491, 0.03153317],
#           [0.0067849 , 0.00708472, 0.00611712, 0.00300477, 0.003077  ,
#            0.00331105, 0.00789117, 0.0033221 , 0.00346795, 0.00333695]])},
#   'accuracy': 69.61904761904762},
#  {'original': {'Dataset': 'MoteStrain',
#    'results': array([0.8370607 , 0.83466454, 0.84265176, 0.83306709, 0.84664537,
#           0.82507987, 0.83067093, 0.82907348, 0.83146965, 0.83386581]),
#    'timings': array([[0.06836912, 0.11016214, 0.10679648, 0.10032508, 0.12592979,
#            0.11807596, 0.1110254 , 0.10024138, 0.10028889, 0.11569093],
#           [3.05818246, 3.10854464, 3.12776059, 3.21517254, 3.15832787,
#            3.30335056, 3.193014  , 3.25853693, 3.06167147, 3.19790207],
#           [0.00748754, 0.00539525, 0.00675797, 0.00694224, 0.00590587,
#            0.00467572, 0.0132424 , 0.00573815, 0.00739159, 0.00559835],
#           [0.02701361, 0.02932361, 0.03341377, 0.02630222, 0.02938864,
#            0.02946701, 0.04259752, 0.02507586, 0.02526426, 0.03151016]])},
#   'accuracy': 83.44249201277954},
#  {'original': {'Dataset': 'ProximalPhalanxTW',
#    'results': array([0.78536585, 0.79512195, 0.79512195, 0.8       , 0.7804878 ,
#           0.77560976, 0.7902439 , 0.8       , 0.7902439 , 0.7804878 ]),
#    'timings': array([[1.00727321, 1.03330569, 1.02524275, 0.98375441, 1.00636685,
#            1.05144528, 1.03330967, 1.03315388, 1.06828245, 1.02221136],
#           [0.53166911, 0.51751595, 0.52262423, 0.51531848, 0.5319037 ,
#            0.51610258, 0.51847693, 0.51832005, 0.5227534 , 0.50343372],
#           [0.24728032, 0.22600115, 0.20346659, 0.26540083, 0.23466883,
#            0.13872788, 0.18191744, 0.17160105, 0.25665996, 0.1959879 ],
#           [0.00673333, 0.00654686, 0.02083782, 0.01414235, 0.01355202,
#            0.01270181, 0.00985707, 0.00651967, 0.00791539, 0.01145245]])},
#   'accuracy': 78.92682926829269},
#  {'original': {'Dataset': 'WordSynonyms',
#    'results': array([0.71003135, 0.71943574, 0.71003135, 0.71003135, 0.71159875,
#           0.70532915, 0.71316614, 0.71316614, 0.71316614, 0.70219436]),
#    'timings': array([[2.14592005, 2.10152991, 2.13722584, 2.20706561, 2.18843682,
#            2.13382035, 2.14730012, 2.13342278, 2.27356746, 2.09944731],
#           [4.93473399, 4.85942208, 4.95336713, 4.97110745, 5.08864773,
#            5.04515574, 4.82196482, 4.9354148 , 4.90735615, 4.77616714],
#           [0.23585983, 0.13000325, 0.18060873, 0.1198387 , 0.1199551 ,
#            0.14228478, 0.12427847, 0.11200681, 0.12307443, 0.10160911],
#           [0.0477793 , 0.04159368, 0.03415984, 0.02922549, 0.03051399,
#            0.03840204, 0.03460016, 0.03232781, 0.02629055, 0.035497  ]])},
#   'accuracy': 71.08150470219437},
#  {'original': {'Dataset': 'Lightning7',
#    'results': array([0.68493151, 0.67123288, 0.71232877, 0.68493151, 0.68493151,
#           0.67123288, 0.68493151, 0.68493151, 0.67123288, 0.69863014]),
#    'timings': array([[0.67096453, 0.66848351, 0.6885328 , 0.68649493, 0.66232107,
#            0.69882851, 0.71071442, 0.72132063, 0.68356313, 0.67168431],
#           [0.68214893, 0.70464649, 0.66761559, 0.66380201, 0.69876817,
#            0.70566652, 0.69497425, 0.68819535, 0.67676407, 0.64329882],
#           [0.04476608, 0.03635372, 0.02240055, 0.03725062, 0.02668454,
#            0.03928103, 0.0162331 , 0.0332087 , 0.02891853, 0.02696972],
#           [0.00428879, 0.00279432, 0.00336435, 0.00366164, 0.00495215,
#            0.0034367 , 0.00357805, 0.00704401, 0.00309273, 0.00448619]])},
#   'accuracy': 68.49315068493149},
#  {'original': {'Dataset': 'GunPointOldVersusYoung',
#    'results': array([0.97142857, 0.97142857, 0.97142857, 0.97142857, 0.97142857,
#           0.97142857, 0.96825397, 0.96825397, 0.97142857, 0.97142857]),
#    'timings': array([[0.58790367, 0.66503137, 0.65937855, 0.6507185 , 0.64491462,
#            0.65355252, 0.62137183, 0.63159429, 0.64392758, 0.7245938 ],
#           [1.34058011, 1.41867199, 1.32655805, 1.36242365, 1.40641413,
#            1.33828732, 1.37778788, 1.37074227, 1.44300808, 1.42918551],
#           [0.05988412, 0.0586312 , 0.04929525, 0.0467165 , 0.06271012,
#            0.0517478 , 0.10093788, 0.10433504, 0.06885224, 0.07368961],
#           [0.00917708, 0.00789196, 0.00907825, 0.01171016, 0.0115086 ,
#            0.01026586, 0.01822507, 0.01211337, 0.01182425, 0.01232999]])},
#   'accuracy': 97.07936507936508},
#  {'original': {'Dataset': 'Earthquakes',
#    'results': array([0.76258993, 0.74820144, 0.77697842, 0.74100719, 0.76258993,
#           0.74820144, 0.75539568, 0.74820144, 0.76258993, 0.74820144]),
#    'timings': array([[4.61934310e+00, 4.74842294e+00, 4.80697877e+00, 4.68888194e+00,
#            4.96103952e+00, 4.74294918e+00, 4.67347939e+00, 4.60877578e+00,
#            4.66406291e+00, 4.70801710e+00],
#           [2.06968722e+00, 1.99794307e+00, 2.00932675e+00, 1.97215332e+00,
#            2.18785656e+00, 2.03244904e+00, 1.95412371e+00, 2.04386629e+00,
#            2.11922320e+00, 2.10768654e+00],
#           [1.74535380e-01, 1.44130199e-01, 1.40369422e-01, 1.40875837e-01,
#            1.20333509e-01, 1.54920767e-01, 1.33131983e-01, 1.42465255e-01,
#            1.34081673e-01, 1.28129263e-01],
#           [6.90392498e-03, 8.35928301e-03, 9.62234498e-03, 8.70324299e-03,
#            8.77149100e-03, 7.30947201e-03, 8.76340200e-03, 7.41581799e-03,
#            5.10435400e-03, 4.15796498e-03]])},
#   'accuracy': 75.53956834532374}]
